# %%
import pandas as pd
df_full = pd.read_csv("../data/csv/raw/BBVA_features.csv", parse_dates=["Date"])
# 🔹 Supongamos que tu DataFrame final se llama df_full
# y tiene una columna 'date' como índice o columna
df_full = df_full.copy()
df_full["eventos_negativos"] = 0  # Por defecto, 0

# =====================================================
# 🧱 1️⃣ Crisis financiera global (2008 - 2009)
# =====================================================
mask_2008 = (df_full["Date"] >= "2008-09-01") & (df_full["Date"] <= "2009-06-30")
df_full.loc[mask_2008, "eventos_negativos"] = 1

# =====================================================
# 🦠 2️⃣ Pandemia COVID-19 (marzo 2020 - junio 2020)
# =====================================================
mask_covid = (df_full["Date"] >= "2020-03-01") & (df_full["Date"] <= "2020-06-30")
df_full.loc[mask_covid, "eventos_negativos"] = 1

# =====================================================
# 💣 3️⃣ Guerra Rusia - Ucrania (febrero 2022 - septiembre 2022)
# =====================================================
mask_ukraine = (df_full["Date"] >= "2022-02-24") & (df_full["Date"] <= "2022-09-30")
df_full.loc[mask_ukraine, "eventos_negativos"] = 1

# =====================================================
# 📉 4️⃣ Burbuja tecnológica (Dot-com crash, 2000 - 2001)
# =====================================================
mask_dotcom = (df_full["Date"] >= "2000-03-01") & (df_full["Date"] <= "2001-03-31")
df_full.loc[mask_dotcom, "eventos_negativos"] = 1

# =====================================================
# 💥 5️⃣ Crisis de deuda europea (julio 2011 - diciembre 2012)
# =====================================================
mask_deuda = (df_full["Date"] >= "2011-07-01") & (df_full["Date"] <= "2012-12-31")
df_full.loc[mask_deuda, "eventos_negativos"] = 1

# =====================================================
# 🏦 6️⃣ Colapso del Silicon Valley Bank (marzo 2023)
# =====================================================
mask_svb = (df_full["Date"] >= "2023-03-10") & (df_full["Date"] <= "2023-04-15")
df_full.loc[mask_svb, "eventos_negativos"] = 1

event_periods = [
    ("2001-09-11", "2001-10-31"),
    ("2000-03-01", "2001-03-31"),
    ("2011-07-01", "2012-12-31"),
    ("2010-05-06", "2010-05-10"),
    ("2008-09-01", "2009-06-30"),
    ("2020-03-01", "2020-06-30"),
    ("2022-02-24", "2022-09-30"),
]

for start, end in event_periods:
    mask = (df_full["Date"] >= start) & (df_full["Date"] <= end)
    df_full.loc[mask, "eventos_negativos"] = 1

# =====================================================
# 🔹 Verificación rápida
# =====================================================
print(df_full["eventos_negativos"].value_counts())
print(df_full[df_full["eventos_negativos"] == 1].head(10))

# =====================================================
# 💾 Guardar versión extendida
# =====================================================
df_full.to_csv("../data/csv/clean/BBVA_macro_extended.csv", index=False)
print("✅ Archivo guardado con columna 'eventos_negativos' añadida.")
# Out:
# eventos_negativos
# 0    5454
# 1    1181
# Name: count, dtype: int64
#          Date  adj close      close       high        low       open  \
# 42 2000-03-01   4.461957  14.651346  14.689775  14.420767  14.555271
# 43 2000-03-02   4.444402  14.593701  14.680168  14.315085  14.651346
# 44 2000-03-03   4.461957  14.651346  14.651346  14.372730  14.651346
# 45 2000-03-06   4.473660  14.689775  15.083680  14.459197  14.891532
# 46 2000-03-07   4.470733  14.680168  14.814672  14.516841  14.622523
# 47 2000-03-08   4.505845  14.795457  14.843494  14.468804  14.593701
# 48 2000-03-09   4.485363  14.728205  14.795457  14.536056  14.795457
# 49 2000-03-10   4.397586  14.439982  14.833887  14.343907  14.728205
# 50 2000-03-13   4.394661  14.430374  14.430374  14.430374  14.430374
# 51 2000-03-14   4.324440  14.199796  14.199796  13.950002  14.199796
#
#       volume     range    return      sma_5     sma_10   vol_rel  \
# 42   9312142  0.269009  0.009934  14.808908  14.739734  0.799880
# 43   7597565  0.365083 -0.003934  14.716676  14.728205  0.666467
# 44   7755245  0.278616  0.003950  14.630210  14.720519  0.718209
# 45  11462949  0.624483  0.002623  14.618681  14.725323  1.054389
# 46   9774752  0.297832 -0.000654  14.653267  14.749342  0.941054
# 47   8594927  0.374690  0.007853  14.682090  14.745499  0.875936
# 48   9151090  0.259401 -0.004545  14.708990  14.712833  1.017151
# 49  11147673  0.489980 -0.019569  14.666718  14.648464  1.228355
# 50         0  0.000000 -0.000665  14.614837  14.616759  0.000000
# 51   6665918  0.249794 -0.015979  14.518763  14.586015  0.818283
#
#     eventos_negativos
# 42                  1
# 43                  1
# 44                  1
# 45                  1
# 46                  1
# 47                  1
# 48                  1
# 49                  1
# 50                  1
# 51                  1
# ✅ Archivo guardado con columna 'eventos_negativos' añadida.

# %%
import pandas as pd

# =====================================================
# 🔹 1️⃣ Cargar DataFrame base del BBVA o Santander
# =====================================================
df_full = pd.read_csv("../data/csv/raw/SAN_features.csv", parse_dates=["Date"])
df_full = df_full.copy()
df_full["eventos_negativos"] = 0  # Por defecto, 0

# =====================================================
# 🧱 2️⃣ Crisis financiera global (2008 - 2009)
# =====================================================
mask_2008 = (df_full["Date"] >= "2008-09-01") & (df_full["Date"] <= "2009-06-30")
df_full.loc[mask_2008, "eventos_negativos"] = 1

# =====================================================
# 🦠 3️⃣ Pandemia COVID-19 (marzo 2020 - junio 2020)
# =====================================================
mask_covid = (df_full["Date"] >= "2020-03-01") & (df_full["Date"] <= "2020-06-30")
df_full.loc[mask_covid, "eventos_negativos"] = 1

# =====================================================
# 💣 4️⃣ Guerra Rusia - Ucrania (febrero 2022 - septiembre 2022)
# =====================================================
mask_ukraine = (df_full["Date"] >= "2022-02-24") & (df_full["Date"] <= "2022-09-30")
df_full.loc[mask_ukraine, "eventos_negativos"] = 1

# =====================================================
# 📉 5️⃣ Burbuja tecnológica (Dot-com crash, 2000 - 2001)
# =====================================================
mask_dotcom = (df_full["Date"] >= "2000-03-01") & (df_full["Date"] <= "2001-03-31")
df_full.loc[mask_dotcom, "eventos_negativos"] = 1

# =====================================================
# 💥 6️⃣ Crisis de deuda europea (julio 2011 - diciembre 2012)
# =====================================================
mask_deuda = (df_full["Date"] >= "2011-07-01") & (df_full["Date"] <= "2012-12-31")
df_full.loc[mask_deuda, "eventos_negativos"] = 1

# =====================================================
# 🏦 7️⃣ Colapso del Silicon Valley Bank (marzo 2023)
# =====================================================
mask_svb = (df_full["Date"] >= "2023-03-10") & (df_full["Date"] <= "2023-04-15")
df_full.loc[mask_svb, "eventos_negativos"] = 1

# =====================================================
# 💀 8️⃣ Muerte de Emilio Botín (presidente Santander)
# =====================================================
mask_botin_muerte = (df_full["Date"] >= "2014-09-10") & (df_full["Date"] <= "2014-09-20")
df_full.loc[mask_botin_muerte, "eventos_negativos"] = 1

# =====================================================
# 👩‍💼 9️⃣ Nombramiento de Ana Botín (nueva presidenta)
# =====================================================
mask_ana_botin = (df_full["Date"] >= "2014-09-20") & (df_full["Date"] <= "2014-10-10")
df_full.loc[mask_ana_botin, "eventos_negativos"] = 1

# =====================================================
# 📆 10️⃣ Otros eventos históricos globales relevantes
# =====================================================
event_periods = [
    ("2001-09-11", "2001-10-31"),  # Atentado Torres Gemelas
    ("2010-05-06", "2010-05-10"),  # Flash Crash
    ("2008-09-01", "2009-06-30"),  # Crisis 2008
    ("2020-03-01", "2020-06-30"),  # COVID
    ("2022-02-24", "2022-09-30"),  # Guerra Ucrania
]

for start, end in event_periods:
    mask = (df_full["Date"] >= start) & (df_full["Date"] <= end)
    df_full.loc[mask, "eventos_negativos"] = 1

# =====================================================
# 🔹 Verificación rápida
# =====================================================
print(df_full["eventos_negativos"].value_counts())
print(df_full[df_full["eventos_negativos"] == 1].head(10))

# =====================================================
# 💾 Guardar versión extendida
# =====================================================
df_full.to_csv("../data/csv/clean/SAN_macro_extended.csv", index=False)
print("✅ Archivo guardado con columna 'eventos_negativos' añadida correctamente.")
# Out:
# eventos_negativos
# 0    5431
# 1    1204
# Name: count, dtype: int64
#          Date  adj close     close      high       low      open    volume  \
# 42 2000-03-01   2.523513  9.416651  9.494546  9.321446  9.477236   9141201
# 43 2000-03-02   2.562941  9.563786  9.589751  9.442616  9.468581  14128833
# 44 2000-03-03   2.537430  9.468581  9.736886  9.433961  9.650336  16796144
# 45 2000-03-06   2.528150  9.433961  9.624371  9.433961  9.624371  12355814
# 46 2000-03-07   2.518873  9.399341  9.563786  9.364721  9.451271  10034784
# 47 2000-03-08   2.539748  9.477236  9.563786  9.347411  9.356066   9208349
# 48 2000-03-09   2.558302  9.546476  9.650336  9.433961  9.485891  14804511
# 49 2000-03-10   2.595414  9.684956  9.684956  9.494546  9.641681  59945035
# 50 2000-03-13   2.593096  9.676301  9.676301  9.676301  9.676301         0
# 51 2000-03-14   2.618607  9.771506  9.771506  9.572441  9.736886  23476575
#
#        range    return     sma_5    sma_10   vol_rel  eventos_negativos
# 42  0.173100 -0.001835  9.392417  9.446944  0.814159                  1
# 43  0.147135  0.015625  9.435692  9.442616  1.289152                  1
# 44  0.302925 -0.009955  9.447809  9.453002  1.554431                  1
# 45  0.190410 -0.003656  9.463388  9.443481  1.108306                  1
# 46  0.199064 -0.003670  9.456464  9.443481  0.912871                  1
# 47  0.216374  0.008287  9.468581  9.430499  0.839193                  1
# 48  0.216375  0.007306  9.465119  9.450405  1.304933                  1
# 49  0.190410  0.014506  9.508394  9.478101  3.667473                  1
# 50  0.000000 -0.000894  9.556862  9.510125  0.000000                  1
# 51  0.199065  0.009839  9.631295  9.543879  1.381859                  1
# ✅ Archivo guardado con columna 'eventos_negativos' añadida correctamente.
